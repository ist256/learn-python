# %% [markdown]
# # Watch Me Code 1: Yes Or No
#
# Our approach
#
# 1. take input "yes" or "no"
# 1. convert to lower case
# 1. slice off first character and return it!

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(str.lower)
# Out:
# Help on method_descriptor:
#
# lower(...)
#     S.lower() -> str
#
#     Return a copy of the string S converted to lowercase.

# %%
x = "MIKE"
s.lower()
# Out:
# 'fudge'

# %%
def YesOrNo(text):
    first_letter = text.lower()[0]
    if first_letter in "yn":
        return first_letter
    else:
        return "error"
    
    
answer = YesOrNo(input("Are you happy [Y/N] ? "))
print (answer)
# Out:
# Are you happy [Y/N] ? yupper
# y
