# %% [markdown]
# # End-To-End Example: Today's Weather
#
# This example will input a location and then output today's current weather conditions at that location.
#
# To complete this example we will use the following API's
#
# - https://www.openstreetmap.org/ Geocode api to get GPS coordinates for a location eg. Syracuse, NY
# - https://openweathermap.org/ forecast api to get the currnt weather conditions for those GPS coordinates

# %%
# Todo list
# input a location eg. Syracuse, ny
# use the google geocode api to get a lat/lng
# use the darksky api and lat/lng to get current weather conditions
# output current weather conditions (temperature and summary (rain, snow, etc...))

# %%
import requests

# %%
def geocode(location):
    query_string = {'q' : location, 'format': 'json'}
    url='https://nominatim.openstreetmap.org/search' 
    response = requests.get(url, params = query_string)
    response.raise_for_status()
    geodata = response.json()
    return geodata
        
# Testing with syracuse, NY 
geocode('Syracuse, NY')
# Out:
# [{'place_id': 257841956,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 174916,
#   'boundingbox': ['42.9843709', '43.086102', '-76.2046029', '-76.074084'],
#   'lat': '43.0481221',
#   'lon': '-76.1474244',
#   'display_name': 'Syracuse, Onondaga County, New York, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6867762857760726,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 69010415,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 6241108067,
#   'boundingbox': ['43.0718312', '43.0818312', '-76.1744003', '-76.1644003'],
#   'lat': '43.0768312',
#   'lon': '-76.1694003',
#   'display_name': 'Syracuse, 131, NBT Bank Parkway, Syracuse, Onondaga County, New York, 13208, United States',
#   'class': 'railway',
#   'type': 'station',
#   'importance': 0.4272524353626238,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//transport_train_station2.p.20.png'},
#  {'place_id': 38569226,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 2997656284,
#   'boundingbox': ['43.0770382', '43.0771382', '-76.1700021', '-76.1699021'],
#   'lat': '43.0770882',
#   'lon': '-76.1699521',
#   'display_name': 'Syracuse, Walsh Circle, Syracuse, Onondaga County, New York, 13290, United States',
#   'class': 'railway',
#   'type': 'stop',
#   'importance': 0.11100000000000002}]

# %%
def getweather(lat,lon):
    key = '67f9d45c32dd086df27f2b7a90370a8e' # sign up for your own key at https://openweathermap.org/ 
    query_string = { 'lat' : lat, 'lon': lon, 'appid' : key, 'units' : 'imperial'}
    url='https://api.openweathermap.org/data/2.5/onecall' 
    response = requests.get(url, params=query_string)
    response.raise_for_status()
    #print (response.url)
    weather = response.json()
    return weather

# Testing with syracuse, NY coordinates
getweather( 43.0481221, -76.1474244 )
# Out:
# {'lat': 43.0481,
#  'lon': -76.1474,
#  'timezone': 'America/New_York',
#  'timezone_offset': -18000,
#  'current': {'dt': 1611164559,
#   'sunrise': 1611145801,
#   'sunset': 1611180060,
#   'temp': 25.48,
#   'feels_like': 7.07,
#   'pressure': 1016,
#   'humidity': 63,
#   'dew_point': 15.85,
#   'uvi': 0.94,
#   'clouds': 90,
#   'visibility': 8047,
#   'wind_speed': 23.02,
#   'wind_deg': 280,
#   'wind_gust': 27.63,
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13d'}]},
#  'hourly': [{'dt': 1611162000,
#    'temp': 25.48,
#    'feels_like': 10.81,
#    'pressure': 1016,
#    'humidity': 63,
#    'dew_point': 15.85,
#    'uvi': 1.04,
#    'clouds': 90,
#    'visibility': 10000,
#    'wind_speed': 16.35,
#    'wind_deg': 296,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.89},
#   {'dt': 1611165600,
#    'temp': 25.25,
#    'feels_like': 10.81,
#    'pressure': 1016,
#    'humidity': 77,
#    'dew_point': 19.76,
#    'uvi': 0.94,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 16.6,
#    'wind_deg': 298,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.87},
#   {'dt': 1611169200,
#    'temp': 24.17,
#    'feels_like': 10.08,
#    'pressure': 1017,
#    'humidity': 84,
#    'dew_point': 20.52,
#    'uvi': 0.71,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 16.15,
#    'wind_deg': 297,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.09},
#   {'dt': 1611172800,
#    'temp': 22.73,
#    'feels_like': 9,
#    'pressure': 1017,
#    'humidity': 88,
#    'dew_point': 20.05,
#    'uvi': 0.37,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 15.48,
#    'wind_deg': 292,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.07},
#   {'dt': 1611176400,
#    'temp': 21.42,
#    'feels_like': 9.3,
#    'pressure': 1018,
#    'humidity': 89,
#    'dew_point': 18.99,
#    'uvi': 0.12,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 12.44,
#    'wind_deg': 293,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.01},
#   {'dt': 1611180000,
#    'temp': 19.35,
#    'feels_like': 9,
#    'pressure': 1018,
#    'humidity': 90,
#    'dew_point': 11.28,
#    'uvi': 0,
#    'clouds': 86,
#    'visibility': 10000,
#    'wind_speed': 9.01,
#    'wind_deg': 290,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.01},
#   {'dt': 1611183600,
#    'temp': 18.03,
#    'feels_like': 8.82,
#    'pressure': 1018,
#    'humidity': 91,
#    'dew_point': 10.83,
#    'uvi': 0,
#    'clouds': 72,
#    'visibility': 10000,
#    'wind_speed': 6.85,
#    'wind_deg': 281,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1611187200,
#    'temp': 17.89,
#    'feels_like': 9.55,
#    'pressure': 1018,
#    'humidity': 91,
#    'dew_point': 11.21,
#    'uvi': 0,
#    'clouds': 75,
#    'visibility': 10000,
#    'wind_speed': 5.26,
#    'wind_deg': 264,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1611190800,
#    'temp': 18.39,
#    'feels_like': 10.6,
#    'pressure': 1017,
#    'humidity': 92,
#    'dew_point': 12.22,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.43,
#    'wind_deg': 249,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1611194400,
#    'temp': 17.89,
#    'feels_like': 10.2,
#    'pressure': 1017,
#    'humidity': 93,
#    'dew_point': 12.45,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.18,
#    'wind_deg': 216,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1611198000,
#    'temp': 18.27,
#    'feels_like': 9.95,
#    'pressure': 1016,
#    'humidity': 93,
#    'dew_point': 13.15,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.37,
#    'wind_deg': 200,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1611201600,
#    'temp': 18.64,
#    'feels_like': 9.68,
#    'pressure': 1016,
#    'humidity': 93,
#    'dew_point': 13.05,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.55,
#    'wind_deg': 192,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1611205200,
#    'temp': 19.29,
#    'feels_like': 9.28,
#    'pressure': 1015,
#    'humidity': 93,
#    'dew_point': 13.46,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 8.52,
#    'wind_deg': 185,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1611208800,
#    'temp': 20.39,
#    'feels_like': 8.94,
#    'pressure': 1013,
#    'humidity': 93,
#    'dew_point': 14.95,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 11.23,
#    'wind_deg': 186,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1611212400,
#    'temp': 21.9,
#    'feels_like': 10.51,
#    'pressure': 1012,
#    'humidity': 93,
#    'dew_point': 16,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 11.39,
#    'wind_deg': 182,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1611216000,
#    'temp': 22.03,
#    'feels_like': 10.11,
#    'pressure': 1010,
#    'humidity': 92,
#    'dew_point': 15.91,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 12.28,
#    'wind_deg': 184,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1611219600,
#    'temp': 22.39,
#    'feels_like': 10.45,
#    'pressure': 1009,
#    'humidity': 92,
#    'dew_point': 16.07,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 12.39,
#    'wind_deg': 191,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1611223200,
#    'temp': 23,
#    'feels_like': 11.14,
#    'pressure': 1007,
#    'humidity': 93,
#    'dew_point': 17.44,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 7519,
#    'wind_speed': 12.39,
#    'wind_deg': 195,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.01},
#   {'dt': 1611226800,
#    'temp': 24.21,
#    'feels_like': 12.15,
#    'pressure': 1006,
#    'humidity': 95,
#    'dew_point': 19.94,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 6370,
#    'wind_speed': 13.06,
#    'wind_deg': 203,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.37,
#    'snow': {'1h': 0.11}},
#   {'dt': 1611230400,
#    'temp': 25.07,
#    'feels_like': 13.44,
#    'pressure': 1005,
#    'humidity': 96,
#    'dew_point': 21.52,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 975,
#    'wind_speed': 12.5,
#    'wind_deg': 210,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.31,
#    'snow': {'1h': 0.13}},
#   {'dt': 1611234000,
#    'temp': 26.82,
#    'feels_like': 14.9,
#    'pressure': 1005,
#    'humidity': 95,
#    'dew_point': 22.95,
#    'uvi': 0.07,
#    'clouds': 100,
#    'visibility': 1539,
#    'wind_speed': 13.33,
#    'wind_deg': 214,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.62,
#    'snow': {'1h': 0.12}},
#   {'dt': 1611237600,
#    'temp': 29.21,
#    'feels_like': 16.52,
#    'pressure': 1004,
#    'humidity': 93,
#    'dew_point': 23.27,
#    'uvi': 0.29,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 15.08,
#    'wind_deg': 218,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.54},
#   {'dt': 1611241200,
#    'temp': 30.94,
#    'feels_like': 17.92,
#    'pressure': 1003,
#    'humidity': 93,
#    'dew_point': 24.24,
#    'uvi': 0.6,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 16.06,
#    'wind_deg': 222,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.54},
#   {'dt': 1611244800,
#    'temp': 32.07,
#    'feels_like': 19.24,
#    'pressure': 1002,
#    'humidity': 94,
#    'dew_point': 26.49,
#    'uvi': 0.77,
#    'clouds': 92,
#    'visibility': 10000,
#    'wind_speed': 16.08,
#    'wind_deg': 225,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.47},
#   {'dt': 1611248400,
#    'temp': 33.26,
#    'feels_like': 20.77,
#    'pressure': 1001,
#    'humidity': 92,
#    'dew_point': 28.94,
#    'uvi': 0.89,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 15.61,
#    'wind_deg': 227,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.51},
#   {'dt': 1611252000,
#    'temp': 34.23,
#    'feels_like': 21.72,
#    'pressure': 1000,
#    'humidity': 89,
#    'dew_point': 30.06,
#    'uvi': 0.81,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 15.7,
#    'wind_deg': 231,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.56},
#   {'dt': 1611255600,
#    'temp': 34.34,
#    'feels_like': 22.1,
#    'pressure': 1000,
#    'humidity': 90,
#    'dew_point': 30.87,
#    'uvi': 0.6,
#    'clouds': 90,
#    'visibility': 8442,
#    'wind_speed': 15.32,
#    'wind_deg': 235,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.53,
#    'snow': {'1h': 0.15}},
#   {'dt': 1611259200,
#    'temp': 34.11,
#    'feels_like': 22.77,
#    'pressure': 999,
#    'humidity': 91,
#    'dew_point': 31.37,
#    'uvi': 0.3,
#    'clouds': 93,
#    'visibility': 4955,
#    'wind_speed': 13.73,
#    'wind_deg': 237,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.57,
#    'snow': {'1h': 0.24}},
#   {'dt': 1611262800,
#    'temp': 33.64,
#    'feels_like': 22.96,
#    'pressure': 1000,
#    'humidity': 93,
#    'dew_point': 31.39,
#    'uvi': 0.1,
#    'clouds': 95,
#    'visibility': 482,
#    'wind_speed': 12.55,
#    'wind_deg': 240,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.58,
#    'snow': {'1h': 0.26}},
#   {'dt': 1611266400,
#    'temp': 32.92,
#    'feels_like': 22.78,
#    'pressure': 1000,
#    'humidity': 95,
#    'dew_point': 31.01,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 226,
#    'wind_speed': 11.54,
#    'wind_deg': 239,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.59,
#    'snow': {'1h': 0.28}},
#   {'dt': 1611270000,
#    'temp': 32.47,
#    'feels_like': 22.39,
#    'pressure': 1000,
#    'humidity': 96,
#    'dew_point': 30.56,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 384,
#    'wind_speed': 11.41,
#    'wind_deg': 239,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.56,
#    'snow': {'1h': 0.32}},
#   {'dt': 1611273600,
#    'temp': 32.4,
#    'feels_like': 21.96,
#    'pressure': 1000,
#    'humidity': 97,
#    'dew_point': 30.49,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 231,
#    'wind_speed': 12.1,
#    'wind_deg': 242,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.68,
#    'snow': {'1h': 0.34}},
#   {'dt': 1611277200,
#    'temp': 31.93,
#    'feels_like': 21.78,
#    'pressure': 1000,
#    'humidity': 98,
#    'dew_point': 29.95,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 263,
#    'wind_speed': 11.54,
#    'wind_deg': 248,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.77,
#    'snow': {'1h': 0.31}},
#   {'dt': 1611280800,
#    'temp': 31.86,
#    'feels_like': 21.69,
#    'pressure': 1000,
#    'humidity': 97,
#    'dew_point': 29.12,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 7310,
#    'wind_speed': 11.48,
#    'wind_deg': 250,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.79,
#    'snow': {'1h': 0.29}},
#   {'dt': 1611284400,
#    'temp': 31.28,
#    'feels_like': 21.11,
#    'pressure': 1000,
#    'humidity': 96,
#    'dew_point': 27.77,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 11.27,
#    'wind_deg': 248,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.71},
#   {'dt': 1611288000,
#    'temp': 30.24,
#    'feels_like': 19.78,
#    'pressure': 1001,
#    'humidity': 97,
#    'dew_point': 27.52,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 555,
#    'wind_speed': 11.59,
#    'wind_deg': 255,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.89,
#    'snow': {'1h': 0.17}},
#   {'dt': 1611291600,
#    'temp': 30.78,
#    'feels_like': 19.62,
#    'pressure': 1001,
#    'humidity': 96,
#    'dew_point': 27.45,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 12.91,
#    'wind_deg': 264,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.89,
#    'snow': {'1h': 0.16}},
#   {'dt': 1611295200,
#    'temp': 29.46,
#    'feels_like': 18.75,
#    'pressure': 1001,
#    'humidity': 96,
#    'dew_point': 26.06,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 11.81,
#    'wind_deg': 262,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.89},
#   {'dt': 1611298800,
#    'temp': 28.4,
#    'feels_like': 17.8,
#    'pressure': 1002,
#    'humidity': 96,
#    'dew_point': 25.02,
#    'uvi': 0,
#    'clouds': 88,
#    'visibility': 10000,
#    'wind_speed': 11.36,
#    'wind_deg': 260,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.31},
#   {'dt': 1611302400,
#    'temp': 27.45,
#    'feels_like': 16.93,
#    'pressure': 1003,
#    'humidity': 96,
#    'dew_point': 23.9,
#    'uvi': 0,
#    'clouds': 79,
#    'visibility': 10000,
#    'wind_speed': 11.03,
#    'wind_deg': 255,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.39},
#   {'dt': 1611306000,
#    'temp': 26.8,
#    'feels_like': 16.38,
#    'pressure': 1003,
#    'humidity': 96,
#    'dew_point': 23.04,
#    'uvi': 0,
#    'clouds': 68,
#    'visibility': 10000,
#    'wind_speed': 10.71,
#    'wind_deg': 253,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.39},
#   {'dt': 1611309600,
#    'temp': 26.17,
#    'feels_like': 16.32,
#    'pressure': 1003,
#    'humidity': 96,
#    'dew_point': 22.42,
#    'uvi': 0,
#    'clouds': 61,
#    'visibility': 10000,
#    'wind_speed': 9.57,
#    'wind_deg': 249,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.4},
#   {'dt': 1611313200,
#    'temp': 25.57,
#    'feels_like': 16.03,
#    'pressure': 1004,
#    'humidity': 96,
#    'dew_point': 21.88,
#    'uvi': 0,
#    'clouds': 58,
#    'visibility': 10000,
#    'wind_speed': 8.9,
#    'wind_deg': 245,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.37},
#   {'dt': 1611316800,
#    'temp': 25.65,
#    'feels_like': 16.05,
#    'pressure': 1005,
#    'humidity': 95,
#    'dew_point': 21.88,
#    'uvi': 0,
#    'clouds': 62,
#    'visibility': 10000,
#    'wind_speed': 8.97,
#    'wind_deg': 242,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.37},
#   {'dt': 1611320400,
#    'temp': 25.68,
#    'feels_like': 15.87,
#    'pressure': 1005,
#    'humidity': 95,
#    'dew_point': 21.7,
#    'uvi': 0.08,
#    'clouds': 60,
#    'visibility': 10000,
#    'wind_speed': 9.35,
#    'wind_deg': 234,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.24},
#   {'dt': 1611324000,
#    'temp': 27.73,
#    'feels_like': 16.63,
#    'pressure': 1006,
#    'humidity': 95,
#    'dew_point': 23.27,
#    'uvi': 0.3,
#    'clouds': 52,
#    'visibility': 10000,
#    'wind_speed': 12.08,
#    'wind_deg': 240,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.24},
#   {'dt': 1611327600,
#    'temp': 29.41,
#    'feels_like': 17.47,
#    'pressure': 1006,
#    'humidity': 95,
#    'dew_point': 24.84,
#    'uvi': 0.63,
#    'clouds': 62,
#    'visibility': 10000,
#    'wind_speed': 13.91,
#    'wind_deg': 249,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.24},
#   {'dt': 1611331200,
#    'temp': 30.33,
#    'feels_like': 18.54,
#    'pressure': 1006,
#    'humidity': 96,
#    'dew_point': 26.49,
#    'uvi': 0.84,
#    'clouds': 71,
#    'visibility': 7307,
#    'wind_speed': 13.94,
#    'wind_deg': 262,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.38,
#    'snow': {'1h': 0.13}}],
#  'daily': [{'dt': 1611162000,
#    'sunrise': 1611145801,
#    'sunset': 1611180060,
#    'temp': {'day': 25.48,
#     'min': 17.89,
#     'max': 27.46,
#     'night': 18.64,
#     'eve': 18.03,
#     'morn': 27.3},
#    'feels_like': {'day': 10.81, 'night': 9.68, 'eve': 8.82, 'morn': 18.63},
#    'pressure': 1016,
#    'humidity': 63,
#    'dew_point': 15.85,
#    'wind_speed': 16.35,
#    'wind_deg': 296,
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13d'}],
#    'clouds': 90,
#    'pop': 0.89,
#    'snow': 2.72,
#    'uvi': 1.04},
#   {'dt': 1611248400,
#    'sunrise': 1611232160,
#    'sunset': 1611266537,
#    'temp': {'day': 33.26,
#     'min': 19.29,
#     'max': 34.34,
#     'night': 30.24,
#     'eve': 32.47,
#     'morn': 24.21},
#    'feels_like': {'day': 20.77, 'night': 19.78, 'eve': 22.39, 'morn': 12.15},
#    'pressure': 1001,
#    'humidity': 92,
#    'dew_point': 28.94,
#    'wind_speed': 15.61,
#    'wind_deg': 227,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 94,
#    'pop': 0.89,
#    'snow': 2.72,
#    'uvi': 0.89},
#   {'dt': 1611334800,
#    'sunrise': 1611318516,
#    'sunset': 1611353014,
#    'temp': {'day': 31.21,
#     'min': 21.33,
#     'max': 31.32,
#     'night': 21.33,
#     'eve': 25.86,
#     'morn': 25.57},
#    'feels_like': {'day': 19.51, 'night': 8.85, 'eve': 13.37, 'morn': 16.03},
#    'pressure': 1006,
#    'humidity': 95,
#    'dew_point': 26.58,
#    'wind_speed': 13.91,
#    'wind_deg': 275,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 76,
#    'pop': 0.89,
#    'snow': 2.57,
#    'uvi': 0.98},
#   {'dt': 1611421200,
#    'sunrise': 1611404870,
#    'sunset': 1611439492,
#    'temp': {'day': 17.85,
#     'min': 16.21,
#     'max': 20.91,
#     'night': 16.21,
#     'eve': 17.82,
#     'morn': 17.94},
#    'feels_like': {'day': 3.9, 'night': 5.95, 'eve': 7.09, 'morn': 4.91},
#    'pressure': 1023,
#    'humidity': 94,
#    'dew_point': 13.17,
#    'wind_speed': 15.32,
#    'wind_deg': 308,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 100,
#    'pop': 0.71,
#    'snow': 2.47,
#    'uvi': 1.01},
#   {'dt': 1611507600,
#    'sunrise': 1611491223,
#    'sunset': 1611525970,
#    'temp': {'day': 19.33,
#     'min': 7.16,
#     'max': 19.33,
#     'night': 12.63,
#     'eve': 14.34,
#     'morn': 7.16},
#    'feels_like': {'day': 10.58, 'night': 5.43, 'eve': 8.46, 'morn': 0.09},
#    'pressure': 1025,
#    'humidity': 91,
#    'dew_point': 12.24,
#    'wind_speed': 6.22,
#    'wind_deg': 315,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': 54,
#    'pop': 0,
#    'uvi': 2},
#   {'dt': 1611594000,
#    'sunrise': 1611577573,
#    'sunset': 1611612449,
#    'temp': {'day': 21.36,
#     'min': 13.62,
#     'max': 21.36,
#     'night': 15.98,
#     'eve': 16.74,
#     'morn': 14.32},
#    'feels_like': {'day': 13.23, 'night': 9.43, 'eve': 9.48, 'morn': 7.29},
#    'pressure': 1015,
#    'humidity': 93,
#    'dew_point': 16.02,
#    'wind_speed': 5.5,
#    'wind_deg': 324,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 96,
#    'pop': 0.3,
#    'snow': 0.56,
#    'uvi': 2},
#   {'dt': 1611680400,
#    'sunrise': 1611663921,
#    'sunset': 1611698928,
#    'temp': {'day': 20.55,
#     'min': 9.9,
#     'max': 20.55,
#     'night': 13.33,
#     'eve': 16.52,
#     'morn': 9.9},
#    'feels_like': {'day': 12.47, 'night': 7.3, 'eve': 8.31, 'morn': 3.54},
#    'pressure': 1018,
#    'humidity': 93,
#    'dew_point': 15.15,
#    'wind_speed': 5.28,
#    'wind_deg': 315,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 99,
#    'pop': 0.2,
#    'snow': 0.16,
#    'uvi': 2},
#   {'dt': 1611766800,
#    'sunrise': 1611750267,
#    'sunset': 1611785407,
#    'temp': {'day': 16.66,
#     'min': 9.19,
#     'max': 17.06,
#     'night': 10.89,
#     'eve': 13.17,
#     'morn': 9.19},
#    'feels_like': {'day': 7.92, 'night': 3.18, 'eve': 4.91, 'morn': 1.56},
#    'pressure': 1026,
#    'humidity': 93,
#    'dew_point': 11.16,
#    'wind_speed': 5.88,
#    'wind_deg': 327,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 96,
#    'pop': 0.34,
#    'snow': 0.7,
#    'uvi': 2}]}

# %%
# then test them here to figue out how to extract from the dictionary
geodata = geocode('Syracuse, NY')
lat = geodata[0]['lat']
lon = geodata[0]['lon']
weather = getweather(lat, lon)
weather['current']
# Out:
# {'dt': 1610994784,
#  'sunrise': 1610973078,
#  'sunset': 1611007110,
#  'temp': 30.04,
#  'feels_like': 18.68,
#  'pressure': 1007,
#  'humidity': 69,
#  'dew_point': 22.12,
#  'uvi': 0.63,
#  'clouds': 90,
#  'visibility': 10000,
#  'wind_speed': 11.5,
#  'wind_deg': 270,
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}]}

# %%
import requests
# Now I can write the entire program...
location = input("Where are you? (eg. Syracuse, NY) : ")
geodata = geocode(location)
lat,lon = geodata[0]['lat'], geodata[0]['lon']
weather = getweather(lat,lon)
current = weather['current']
print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# Where are you? (eg. Syracuse, NY) :  Syracuse, NY
# Current conditions in Syracuse, NY are overcast clouds with a temperature of 30.04 degrees.

# %%
from IPython.display import display, HTML
from ipywidgets import interact_manual
import requests

display(HTML("<h1>Weather Forecaster</h1>"))
@interact_manual(location="")
def main(location):
    geodata = geocode(location)
    lat,lon = geodata[0]['lat'], geodata[0]['lon']
    weather = getweather(lat,lon)
    current = weather['current']
    print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# <h1>Weather Forecaster</h1>
# interactive(children=(Text(value='', description='location'), Button(description='Run Interact', style=ButtonS…
