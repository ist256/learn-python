# %% [markdown]
# # End-To-End Example: Plotting and Mapping Potholes
#
# Let's do a data analysis of Syracuse Potholes based on data from the civic hackathon https://cityofsyracuse.github.io/RoadsChallenge/
#
# We will plot data and display pothole locations on a map!

# %%
import folium
import pandas as pd

# %% [markdown]
# First we need to find the latitude and longitude of Syracuse, then estimate the appropriate zoom level...

# %%
SYR = (43.0481, -76.1474)
map = folium.Map(location=SYR, zoom_start=14)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# We get the data from the RoadsChallange github account

# %%
data = pd.read_csv('https://cityofsyracuse.github.io/RoadsChallenge/data/potholes.csv')
data.sample(5)
# Out:
#      StreetNumber   StreetName StreetNamePostType Directional  \
# 6644         1935      VALLEY                  DR
# 6842          600       LYNCH                 AVE
# 787           406     ACADEMY                  PL
# 3178          141     CORDOVA                  ST
# 3741          428    FRANKLIN                  ST          N
# 3298          244        GLEN                 AVE          E
# 1418          321     GRANGER                  ST
# 2341          115     CONIFER                  DR
# 7530          101      GEDDES                  ST          S
# 3628          112   WILKINSON                  ST
# 896           111     CHAFFEE                 AVE          E
# 6329          142    LYNHURST                 AVE          W
# 910           119    NORMANOR                  DR
# 4459          114      BARNES                 AVE
# 5040         1223  JAMESVILLE                 AVE
# 5394          373     OAKWOOD                 AVE
# 6294          800      IRVING                 AVE
# 2951          343    CORTLAND                 AVE
# 4400          726      NEWELL                  ST          W
# 4655          149     MAXWELL                 AVE
# 2832          184  WARRINGTON                  RD          E
# 2641          253   GREENWOOD                  PL
# 5591          923      GEDDES                  ST          S
# 5065          153     AINSLEY                  DR
# 1121          134      FISCOE                 AVE
# 4056          300    ATLANTIC                 AVE
# 1056          106  WARRINGTON                  RD          W
# 3291          338    RANDOLPH                  ST
# 3984          337     SHIRLEY                  DR
# 5187          208    DRISCOLL                 AVE
# 2305          143     CONIFER                  DR
# 4286          316  MARGUERITE                 AVE
# 7534          735        ERIE                BLVD          W
# 3088          425  JAMESVILLE                 AVE
# 2140          218  STRATHMORE                  DR
# 209           500    CORTLAND                 AVE
# 3632          112   WILKINSON                  ST
# 1960          109        EDNA                  RD
# 7187         1424       STATE                  ST          N
# 6148          705      WALNUT                 AVE
# 1190          109     BISSELL                  ST          E
# 5201          200    DRISCOLL                 AVE
# 5238          316       ESSEX                  ST
# 4549          148        CAMP                 AVE
# 2858          238      SENECA                TNPK          E
# 244           468    CORTLAND                 AVE
# 1666          109     PARRISH                  LN
# 5589          115    FORDLAND                 AVE
# 1565          700  WASHINGTON                  ST          E
# 1840         3123      SALINA                  ST          S
# 4589          822      VALLEY                  DR
# 3616          101   WILKINSON                  ST
# 6333          146    LYNHURST                 AVE          W
# 2037          121     FAYETTE                  ST          W
# 832           403     HOEFLER                  ST
#
#                                             strLocation           dtTime  \
# 6644  1935 VALLEY DR                                ...   8/12/2016 6:32
# 6842  600 LYNCH AVE & MITCHELL AVE                  ...   8/18/2016 8:06
# 787                                      406 ACADEMY PL   4/19/2016 9:58
# 3178                       141 CORDOVA ST & SPRINGBROOK  5/16/2016 10:04
# 3741                                  428 FRANKLIN ST N  5/19/2016 14:24
# 3298                           244 GLEN AVE E & OTTO ST   5/17/2016 9:05
# 1418                        321 GRANGER ST & SEYMOUR ST  4/22/2016 11:24
#
#       STREET_ID VehicleName   Latitude  Longitude
# 6644   12571709         DP2 -76.152834  42.996625
# 6842   12571819         DP2 -76.170285  43.014470
# 787    12576486         DP2 -76.151262  42.992400
# 3178   12576651         DP2 -76.138817  43.006650
# 3741   12573962         DP1 -76.155251  43.055283
# 3298   12576634         DP1 -76.140367  43.005021
# 1418   13009794         DP1 -76.155696  43.042538
# 2341   12564411         DP2 -76.142625  42.990603
# 7530   13002381         DP2 -76.169834  43.047997
# 3628   12573772         DP1 -76.162037  43.051179
# 896    12576512         DP2 -76.151676  42.997799
# 6329   12576768         DP2 -76.143090  43.015241
# 910    12576513         DP2 -76.150503  42.996835
# 4459   12571902         DP1 -76.160587  43.011994
# 5040   12576927         DP1 -76.126253  43.013719
# 5394   12577360         DP1 -76.145237  43.035646
# 6294   12577490         DP2 -76.138278  43.038659
# 2951   12573240         DP2 -76.152635  43.032837
# 4400   12571967         DP1 -76.158811  43.016376
# 4655   12571760         DP1 -76.156932  43.005891
# 2832   12576526         DP2 -76.140139  42.994132
# 2641   12578169         DP2 -76.122146  43.040793
# 5591   12573092         DP1 -76.172933  43.038555
# 5065   12576914         DP1 -76.131481  43.011206
# 1121   12576504         DP2 -76.145362  42.992793
# 4056   12571953         DP1 -76.152664  43.010788
# 1056   12576511         DP2 -76.143898  42.994489
# 3291   12576618         DP2 -76.141647  43.003247
# 3984   12571937         DP1 -76.154821  43.008445
# 5187   12572758         DP1 -76.197382  43.052947
# 2305   12564411         DP2 -76.140682  42.990613
# 4286   12572073         DP1 -76.159363  43.020004
# 7534   13002381         DP2 -76.169319  43.048002
# 3088   13002071         DP1 -76.133293  43.021657
# 2140   12571883         DP2 -76.172502  43.021137
# 209    12573214         DP2 -76.156027  43.029939
# 3632   12573772         DP1 -76.162040  43.051477
# 1960   12564393         DP2 -76.141600  42.985101
# 7187   12575161         DP2 -76.158245  43.064937
# 6148   12578112         DP2 -76.132191  43.042702
# 1190   12573177         DP1 -76.158228  43.025589
# 5201   12572758         DP1 -76.196662  43.053131
# 5238   12572773         DP1 -76.198615  43.054492
# 4549   12571771         DP1 -76.157817  43.007951
# 2858   12576560         DP2 -76.138732  42.999808
# 244    12573231         DP1 -76.155747  43.030074
# 1666   12564398         DP2 -76.142420  42.986143
# 5589   12580564         DP1 -76.150934  43.077090
# 1565   12577797         DP2 -76.142203  43.049389
# 1840   13012959         DP2 -76.141449  43.017266
# 4589   12571771         DP1 -76.156279  43.008051
# 3616   12573773         DP1 -76.161422  43.050390
# 6333   12576768         DP2 -76.143481  43.015240
# 2037   12573749         DP2 -76.153513  43.048391
# 832    12572998         DP1 -76.179332  43.033099

# %% [markdown]
# Now we take the latitude and longitude of each pothole and show them on a map using circle markers

# %%
# NOTE: to_dict('records') converts a pandas dataframe back to a list of dict!
SYR = (43.0481, -76.1474)
map = folium.Map(location=SYR, zoom_start=14)
subset = data.sample(500)
for row in subset.to_records():
    coords = (row['Longitude'],row['Latitude'])
    loc = str(row['strLocation']) + ' ' + str(row['dtTime'])
    marker = folium.CircleMarker(location=coords, radius=15, popup=loc,color='#3186cc',fill_color='#3186cc')
    map.add_children(marker)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
