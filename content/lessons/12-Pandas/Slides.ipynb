# %% [markdown]
# # IST256 Lesson 12
# ## Data Analysis
#
#
# - Reading
#    - https://ist256.github.io/spring2020/readings/Data-Analysis-With-Pandas.html
#
#
# ## Links
#
# - Participation: [https://poll.ist256.com](https://poll.ist256.com)
# - Zoom Chat!

# %% [markdown]
# # Agenda
#
# - The Project
# - Homework Solution
#
# - What is Data Analysis?
# - What is Pandas?
# - How to perform data analysis with Pandas
# - Example

# %% [markdown]
# # The Project (49/250 points)
#
# - P1 => 5/3 Ideation and components
# - P2 => 5/11 1st draft of code
# - P3 => 5/19 Final Code
# - P4 => 5/19 Video demo; video reflection
#
# - jupyterhub `library/ist256/lessons/project` folder
# - Syllabus for details http://ist256.com/syllabus/#project-p1-p4
# - Examples of project? ETEE, Smallgroup, Homework, these are examples of C level projects. Higher grades require use of more  components, novel components and thus lines of code.

# %% [markdown]
# # Connect Activity
#
# #### Question:
# The process of systematically applying techniques to evaluate data is known as ?
# A. Data Munging
# B. Data Analysis
# C. Data Science
# D. Data Bases
#
# ### Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# # Data Analysis:
#
# - **What is it?**
#     - Apply logical techniques to
#     - Describe, condense, recap and evaluate Data and
#     - Illustrate Information
#
#
# - **Goals of Data Analysis:**
#     1. Discover useful information
#     2. Provide insights
#     3. Suggest conclusions
#     4. Support Decision Making

# %% [markdown]
# # What is pandas ?
#
# - ***Pandas*** is Python package for **data analysis.**
# - It allows you to fetch data from a variety of sources and tablualize it.
# - It Provides built-in data structures which simplify the manipulation and analysis of data sets.
# - Pandas is easy to use and powerful, but “with great power comes great responsibility”
# - We cannot teach you all things Pandas, we must focus on how it works, so you can figure out the rest on your own.
# - http://pandas.pydata.org/pandas-docs/stable/

# %% [markdown]
# # Pandas is the next theme...
#
# ... In a common thread.
#
# - We learned about lists and files
# - Then we learned about dictionaries, JSON format and Python data structures
# - Then we learned about calling API's and re-serializing JSON to Python data structures
# - Now we will learn to load and manipulate tabular data structures

# %% [markdown]
# # Pandas: Essential Concepts
#
# - A **Series** is a named Python list (dict with list as value).
#    `{ ‘grades’ : [50,90,100,45] }`
# - A **DataFrame** is a dictionary of Series (dict of series):
#   `{  { ‘names’ : [‘bob’,’ken’,’art’,’joe’] } , { ‘grades’ : [50,90,100,45] }  }`

# %% [markdown]
# # Watch Me Code 1
#
# ### Pandas Basics
# - Series
# - DataFrame
# - Creating a DataFrame from a dict
# - Select columns, Select rows with Boolean indexing

# %% [markdown]
# # Check Yourself: Series or DataFrame?
#
# #### Match the code to the result. One result is a Series, the other a DataFrame
# `df[‘Quarter’]`
#
# ![image.png](attachment:image.png)
# A.` Series`   B. `Data Frame`
# ### Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# # Check Yourself: Boolean Index
#
# #### Which rows are included in this Boolean index?
# `[ df[‘Sold’] < 110 ]`
# ![image.png](attachment:image.png)
# A. `0, 1, 2`
# B. `1, 2, 3`
# C. `0, 2`
# D. `0,1`
# ### Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
#  # Pandas and DataFrames
#
#  - Pandas can load a wide variety of data into dataframes!
#      - csv / excel / delimited files
#      - database tables and queries
#      - HTML tables on webpages
#      - JSON data
#      - API output
#  - Once its in a DataFrame its easy to explore and manipulate!

# %% [markdown]
# # Watch Me Code 2
#
# ### Pandas Can Read Almost Anything!
# - `read_csv` files in delimited format... (beercalories.txt, fudgemart-products.txt)
# - `read_json` deserialize tabular JSON - stocks.json
# - `read_html` reads table data from a webpage!
# - `pd.DataFrame` to create a dataframe from a Python data structure (openstreet maps geocode)
#
# ### Then basic Some DF manipulations...
# - row/column filters
# - `head()`, `sample()`
# - `value_counts`
# - dealing with nulls `DropNA()`

# %% [markdown]
# # End-To-End Example
#
# ### Searching the UFO Dataset
#
# - 5 months of UFO sightings in 2016: https://github.com/mafudge/datasets/tree/master/ufo-sightings
# - Combine into a single data frame
# - IPYWidgets + Interact to search the dataframe interactively.

# %% [markdown]
# # Conclusion Activity : One Question Quiz
#
# For the following dataframe, `df`
#
# <table style="font-size:1.0em;">
#     <thead><tr>
#         <th>a</th>
#         <th>b</th>
#         <th>c</th>
#     </tr></thead>
#     <tbody>
#     <tr>
#         <td>1</td>
#         <td>x</td>
#         <td>y</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>w</td>
#         <td>y</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>q</td>
#         <td>z</td>
#     </tr>
#     </tbody>
# </table>
#
# what is: `df[ df['c'] =='z' ]['a']`
#
# A. `1`
# B. `3`
# C. `5`
# D. `a`
#
#
# ### Vote Now: [https://poll.ist256.com](https://poll.ist256.com)
