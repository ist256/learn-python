# %% [markdown]
# # End-To-End Example: Today's Weather
#
# This example will input a location and then output today's current weather conditions at that location.
#
# To complete this example we will use the following API's
#
# - Google Geocode api to get GPS coordinates for a location eg. Syracuse, NY
# - Darksky.net forecast api to get the currnt weather conditions for those GPS coordinates

# %%
# Todo list
# input a location eg. Syracuse, ny
# use the google geocode api to get a lat/lng
# use the darksky api and lat/lng to get current weather conditions
# output current weather conditions (temperature and summary (rain, snow, etc...))

# %%
import requests

#first I write these

def google_geocode(location):
    params = {'address' : location, 'key': 'AIzaSyCSzXJNyHpfNDwf_kI5maFxNVN2yjUbFnY'}
    url = 'https://maps.googleapis.com/maps/api/geocode/json'
    response = requests.get(url, params = params)
    if response.ok:
        geodata = response.json()
        if geodata['status'] == 'OK':
            return geodata
        else:
            print("Error calling api!!!")
            print(response.text)            
    else:
        print("Error calling api!!!")
        print(response.text)

def darksky_weather(coords):
    key = '3428d875996cccbf7b713a175d3fd7a5' # sign up for your own key at https://darksky.net/dev 
    url='https://api.darksky.net/forecast/%s/%f,%f' % (key, coords['lat'], coords['lng'])
    #print(url)
    response = requests.get(url)
    weather = response.json()
    return weather


# then test them here
geodata = google_geocode('Syracuse, NY')
geodata
coords =geodata['results'][0]['geometry']['location']
coords
weather = darksky_weather(coords)
weather
# Out:
# https://api.darksky.net/forecast/3428d875996cccbf7b713a175d3fd7a5/43.048122,-76.147424
# {'currently': {'apparentTemperature': 37.05,
#   'cloudCover': 0.66,
#   'dewPoint': 16.42,
#   'humidity': 0.38,
#   'icon': 'partly-cloudy-day',
#   'nearestStormBearing': 198,
#   'nearestStormDistance': 100,
#   'ozone': 400.75,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'pressure': 1021.97,
#   'summary': 'Mostly Cloudy',
#   'temperature': 39.92,
#   'time': 1523298324,
#   'uvIndex': 3,
#   'visibility': 10,
#   'windBearing': 244,
#   'windGust': 5.61,
#   'windSpeed': 4.19},
#  'daily': {'data': [{'apparentTemperatureHigh': 38.91,
#     'apparentTemperatureHighTime': 1523300400,
#     'apparentTemperatureLow': 25.48,
#     'apparentTemperatureLowTime': 1523358000,
#     'apparentTemperatureMax': 38.91,
#     'apparentTemperatureMaxTime': 1523300400,
#     'apparentTemperatureMin': 17.01,
#     'apparentTemperatureMinTime': 1523246400,
#     'cloudCover': 0.38,
#     'dewPoint': 17.43,
#     'humidity': 0.58,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.79,
#     'ozone': 409.56,
#     'precipAccumulation': 0.076,
#     'precipIntensity': 0.0004,
#     'precipIntensityMax': 0.0019,
#     'precipIntensityMaxTime': 1523246400,
#     'precipProbability': 0.17,
#     'precipType': 'snow',
#     'pressure': 1021.66,
#     'summary': 'Mostly cloudy starting in the afternoon.',
#     'sunriseTime': 1523270003,
#     'sunsetTime': 1523317255,
#     'temperatureHigh': 40.96,
#     'temperatureHighTime': 1523304000,
#     'temperatureLow': 28.18,
#     'temperatureLowTime': 1523350800,
#     'temperatureMax': 40.96,
#     'temperatureMaxTime': 1523304000,
#     'temperatureMin': 21.19,
#     'temperatureMinTime': 1523271600,
#     'time': 1523246400,
#     'uvIndex': 4,
#     'uvIndexTime': 1523289600,
#     'visibility': 10,
#     'windBearing': 286,
#     'windGust': 18.68,
#     'windGustTime': 1523246400,
#     'windSpeed': 2.01},
#    {'apparentTemperatureHigh': 38.56,
#     'apparentTemperatureHighTime': 1523390400,
#     'apparentTemperatureLow': 21.78,
#     'apparentTemperatureLowTime': 1523437200,
#     'apparentTemperatureMax': 38.56,
#     'apparentTemperatureMaxTime': 1523390400,
#     'apparentTemperatureMin': 25.48,
#     'apparentTemperatureMinTime': 1523358000,
#     'cloudCover': 0.65,
#     'dewPoint': 21.97,
#     'humidity': 0.63,
#     'icon': 'snow',
#     'moonPhase': 0.82,
#     'ozone': 411.3,
#     'precipAccumulation': 0.518,
#     'precipIntensity': 0.0024,
#     'precipIntensityMax': 0.0089,
#     'precipIntensityMaxTime': 1523354400,
#     'precipProbability': 0.29,
#     'precipType': 'snow',
#     'pressure': 1022.24,
#     'summary': 'Light snow (< 1 in.) in the morning.',
#     'sunriseTime': 1523356301,
#     'sunsetTime': 1523403724,
#     'temperatureHigh': 43.78,
#     'temperatureHighTime': 1523390400,
#     'temperatureLow': 27.02,
#     'temperatureLowTime': 1523437200,
#     'temperatureMax': 43.78,
#     'temperatureMaxTime': 1523390400,
#     'temperatureMin': 28.18,
#     'temperatureMinTime': 1523350800,
#     'time': 1523332800,
#     'uvIndex': 3,
#     'uvIndexTime': 1523376000,
#     'visibility': 9.87,
#     'windBearing': 320,
#     'windGust': 15.56,
#     'windGustTime': 1523394000,
#     'windSpeed': 3.27},
#    {'apparentTemperatureHigh': 51.01,
#     'apparentTemperatureHighTime': 1523473200,
#     'apparentTemperatureLow': 33.6,
#     'apparentTemperatureLowTime': 1523527200,
#     'apparentTemperatureMax': 51.01,
#     'apparentTemperatureMaxTime': 1523473200,
#     'apparentTemperatureMin': 21.78,
#     'apparentTemperatureMinTime': 1523437200,
#     'cloudCover': 0.48,
#     'dewPoint': 27.02,
#     'humidity': 0.66,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.85,
#     'ozone': 407.07,
#     'precipIntensity': 0.0025,
#     'precipIntensityMax': 0.0123,
#     'precipIntensityMaxTime': 1523502000,
#     'precipProbability': 0.21,
#     'precipType': 'rain',
#     'pressure': 1018.43,
#     'summary': 'Partly cloudy in the morning.',
#     'sunriseTime': 1523442600,
#     'sunsetTime': 1523490194,
#     'temperatureHigh': 51.01,
#     'temperatureHighTime': 1523473200,
#     'temperatureLow': 35.98,
#     'temperatureLowTime': 1523523600,
#     'temperatureMax': 51.01,
#     'temperatureMaxTime': 1523473200,
#     'temperatureMin': 27.02,
#     'temperatureMinTime': 1523437200,
#     'time': 1523419200,
#     'uvIndex': 4,
#     'uvIndexTime': 1523462400,
#     'visibility': 10,
#     'windBearing': 221,
#     'windGust': 25.88,
#     'windGustTime': 1523498400,
#     'windSpeed': 7.16},
#    {'apparentTemperatureHigh': 53.83,
#     'apparentTemperatureHighTime': 1523574000,
#     'apparentTemperatureLow': 32.93,
#     'apparentTemperatureLowTime': 1523610000,
#     'apparentTemperatureMax': 56.21,
#     'apparentTemperatureMaxTime': 1523581200,
#     'apparentTemperatureMin': 33.6,
#     'apparentTemperatureMinTime': 1523527200,
#     'cloudCover': 0.95,
#     'dewPoint': 40.56,
#     'humidity': 0.84,
#     'icon': 'rain',
#     'moonPhase': 0.88,
#     'ozone': 391.65,
#     'precipIntensity': 0.0101,
#     'precipIntensityMax': 0.0511,
#     'precipIntensityMaxTime': 1523545200,
#     'precipProbability': 0.58,
#     'precipType': 'rain',
#     'pressure': 1011.19,
#     'summary': 'Light rain until afternoon.',
#     'sunriseTime': 1523528899,
#     'sunsetTime': 1523576664,
#     'temperatureHigh': 53.83,
#     'temperatureHighTime': 1523574000,
#     'temperatureLow': 36.23,
#     'temperatureLowTime': 1523613600,
#     'temperatureMax': 56.21,
#     'temperatureMaxTime': 1523581200,
#     'temperatureMin': 35.98,
#     'temperatureMinTime': 1523523600,
#     'time': 1523505600,
#     'uvIndex': 3,
#     'uvIndexTime': 1523548800,
#     'visibility': 9.74,
#     'windBearing': 211,
#     'windGust': 38.63,
#     'windGustTime': 1523581200,
#     'windSpeed': 5.61},
#    {'apparentTemperatureHigh': 54.99,
#     'apparentTemperatureHighTime': 1523656800,
#     'apparentTemperatureLow': 46.09,
#     'apparentTemperatureLowTime': 1523689200,
#     'apparentTemperatureMax': 54.99,
#     'apparentTemperatureMaxTime': 1523656800,
#     'apparentTemperatureMin': 32.93,
#     'apparentTemperatureMinTime': 1523610000,
#     'cloudCover': 0.92,
#     'dewPoint': 39.23,
#     'humidity': 0.8,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.92,
#     'ozone': 344.52,
#     'precipIntensity': 0.0024,
#     'precipIntensityMax': 0.0128,
#     'precipIntensityMaxTime': 1523620800,
#     'precipProbability': 0.28,
#     'precipType': 'rain',
#     'pressure': 1015.32,
#     'summary': 'Mostly cloudy throughout the day.',
#     'sunriseTime': 1523615199,
#     'sunsetTime': 1523663133,
#     'temperatureHigh': 54.99,
#     'temperatureHighTime': 1523656800,
#     'temperatureLow': 46.33,
#     'temperatureLowTime': 1523685600,
#     'temperatureMax': 54.99,
#     'temperatureMaxTime': 1523656800,
#     'temperatureMin': 36.23,
#     'temperatureMinTime': 1523613600,
#     'time': 1523592000,
#     'uvIndex': 4,
#     'uvIndexTime': 1523638800,
#     'windBearing': 223,
#     'windGust': 28.31,
#     'windGustTime': 1523592000,
#     'windSpeed': 1.53},
#    {'apparentTemperatureHigh': 64.43,
#     'apparentTemperatureHighTime': 1523736000,
#     'apparentTemperatureLow': 40.12,
#     'apparentTemperatureLowTime': 1523786400,
#     'apparentTemperatureMax': 64.43,
#     'apparentTemperatureMaxTime': 1523736000,
#     'apparentTemperatureMin': 43.2,
#     'apparentTemperatureMinTime': 1523761200,
#     'cloudCover': 0.97,
#     'dewPoint': 47.11,
#     'humidity': 0.78,
#     'icon': 'cloudy',
#     'moonPhase': 0.95,
#     'ozone': 328.8,
#     'precipIntensity': 0.0033,
#     'precipIntensityMax': 0.0243,
#     'precipIntensityMaxTime': 1523761200,
#     'precipProbability': 0.37,
#     'precipType': 'rain',
#     'pressure': 1014.98,
#     'summary': 'Overcast throughout the day.',
#     'sunriseTime': 1523701500,
#     'sunsetTime': 1523749603,
#     'temperatureHigh': 64.43,
#     'temperatureHighTime': 1523736000,
#     'temperatureLow': 42.29,
#     'temperatureLowTime': 1523786400,
#     'temperatureMax': 64.43,
#     'temperatureMaxTime': 1523736000,
#     'temperatureMin': 46.18,
#     'temperatureMinTime': 1523761200,
#     'time': 1523678400,
#     'uvIndex': 4,
#     'uvIndexTime': 1523721600,
#     'windBearing': 330,
#     'windGust': 15.75,
#     'windGustTime': 1523718000,
#     'windSpeed': 2.88},
#    {'apparentTemperatureHigh': 56.81,
#     'apparentTemperatureHighTime': 1523815200,
#     'apparentTemperatureLow': 43.02,
#     'apparentTemperatureLowTime': 1523858400,
#     'apparentTemperatureMax': 56.81,
#     'apparentTemperatureMaxTime': 1523815200,
#     'apparentTemperatureMin': 40.12,
#     'apparentTemperatureMinTime': 1523786400,
#     'cloudCover': 1,
#     'dewPoint': 44.76,
#     'humidity': 0.85,
#     'icon': 'rain',
#     'moonPhase': 0.98,
#     'ozone': 321.66,
#     'precipIntensity': 0.0332,
#     'precipIntensityMax': 0.0819,
#     'precipIntensityMaxTime': 1523793600,
#     'precipProbability': 0.74,
#     'precipType': 'rain',
#     'pressure': 1017.29,
#     'summary': 'Rain in the morning and overnight and windy starting in the evening.',
#     'sunriseTime': 1523787801,
#     'sunsetTime': 1523836073,
#     'temperatureHigh': 56.81,
#     'temperatureHighTime': 1523815200,
#     'temperatureLow': 48.26,
#     'temperatureLowTime': 1523858400,
#     'temperatureMax': 56.81,
#     'temperatureMaxTime': 1523815200,
#     'temperatureMin': 42.29,
#     'temperatureMinTime': 1523786400,
#     'time': 1523764800,
#     'uvIndex': 4,
#     'uvIndexTime': 1523808000,
#     'windBearing': 109,
#     'windGust': 39.8,
#     'windGustTime': 1523844000,
#     'windSpeed': 6.44},
#    {'apparentTemperatureHigh': 57.28,
#     'apparentTemperatureHighTime': 1523898000,
#     'apparentTemperatureLow': 29.53,
#     'apparentTemperatureLowTime': 1523966400,
#     'apparentTemperatureMax': 57.28,
#     'apparentTemperatureMaxTime': 1523898000,
#     'apparentTemperatureMin': 43.02,
#     'apparentTemperatureMinTime': 1523858400,
#     'cloudCover': 0.97,
#     'dewPoint': 50.45,
#     'humidity': 0.94,
#     'icon': 'rain',
#     'moonPhase': 0.02,
#     'ozone': 337.38,
#     'precipIntensity': 0.0812,
#     'precipIntensityMax': 0.156,
#     'precipIntensityMaxTime': 1523872800,
#     'precipProbability': 0.89,
#     'precipType': 'rain',
#     'pressure': 1002.9,
#     'summary': 'Rain until evening, starting again overnight.',
#     'sunriseTime': 1523874103,
#     'sunsetTime': 1523922543,
#     'temperatureHigh': 57.28,
#     'temperatureHighTime': 1523898000,
#     'temperatureLow': 36.47,
#     'temperatureLowTime': 1523962800,
#     'temperatureMax': 57.28,
#     'temperatureMaxTime': 1523898000,
#     'temperatureMin': 47.98,
#     'temperatureMinTime': 1523934000,
#     'time': 1523851200,
#     'uvIndex': 4,
#     'uvIndexTime': 1523894400,
#     'windBearing': 158,
#     'windGust': 38.65,
#     'windGustTime': 1523851200,
#     'windSpeed': 2.68}],
#   'icon': 'rain',
#   'summary': 'Mixed precipitation tomorrow through next Monday, with high temperatures rising to 64°F on Saturday.'},
#  'flags': {'isd-stations': ['718200-99999',
#    '725146-54773',
#    '725146-99999',
#    '725155-94761',
#    '725155-99999',
#    '725190-14771',
#    '725194-54778',
#    '725194-99999',
#    '725195-99999',
#    '725196-14717',
#    '725196-64775',
#    '725197-94794',
#    '997264-99999',
#    '999999-14771',
#    '999999-64758',
#    '999999-94781'],
#   'sources': ['isd',
#    'nearest-precip',
#    'nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 35.55,
#     'cloudCover': 0.65,
#     'dewPoint': 15.79,
#     'humidity': 0.38,
#     'icon': 'partly-cloudy-day',
#     'ozone': 400.39,
#     'precipIntensity': 0.0011,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'pressure': 1022.01,
#     'summary': 'Mostly Cloudy',
#     'temperature': 39.16,
#     'time': 1523296800,
#     'uvIndex': 3,
#     'visibility': 10,
#     'windBearing': 234,
#     'windGust': 5.9,
#     'windSpeed': 4.92},
#    {'apparentTemperature': 38.91,
#     'cloudCover': 0.68,
#     'dewPoint': 17.28,
#     'humidity': 0.38,
#     'icon': 'partly-cloudy-day',
#     'ozone': 401.25,
#     'precipIntensity': 0.0001,
#     'precipProbability': 0.08,
#     'precipType': 'rain',
#     'pressure': 1021.92,
#     'summary': 'Mostly Cloudy',
#     'temperature': 40.94,
#     'time': 1523300400,
#     'uvIndex': 3,
#     'visibility': 10,
#     'windBearing': 263,
#     'windGust': 5.21,
#     'windSpeed': 3.48},
#    {'apparentTemperature': 38.68,
#     'cloudCover': 0.71,
#     'dewPoint': 18.7,
#     'humidity': 0.4,
#     'icon': 'partly-cloudy-day',
#     'ozone': 403.42,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1021.75,
#     'summary': 'Mostly Cloudy',
#     'temperature': 40.96,
#     'time': 1523304000,
#     'uvIndex': 2,
#     'visibility': 10,
#     'windBearing': 325,
#     'windGust': 4.88,
#     'windSpeed': 3.73},
#    {'apparentTemperature': 36.82,
#     'cloudCover': 0.8,
#     'dewPoint': 19.59,
#     'humidity': 0.44,
#     'icon': 'partly-cloudy-day',
#     'ozone': 404.61,
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1021.7,
#     'summary': 'Mostly Cloudy',
#     'temperature': 39.85,
#     'time': 1523307600,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 351,
#     'windGust': 5.4,
#     'windSpeed': 4.36},
#    {'apparentTemperature': 33.83,
#     'cloudCover': 0.75,
#     'dewPoint': 20.44,
#     'humidity': 0.49,
#     'icon': 'partly-cloudy-day',
#     'ozone': 403.61,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1021.62,
#     'summary': 'Mostly Cloudy',
#     'temperature': 37.68,
#     'time': 1523311200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 2,
#     'windGust': 6.72,
#     'windSpeed': 4.89},
#    {'apparentTemperature': 32,
#     'cloudCover': 0.88,
#     'dewPoint': 21.1,
#     'humidity': 0.55,
#     'icon': 'partly-cloudy-day',
#     'ozone': 401.63,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.04,
#     'precipType': 'snow',
#     'pressure': 1021.9,
#     'summary': 'Mostly Cloudy',
#     'temperature': 35.85,
#     'time': 1523314800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 10,
#     'windGust': 7.53,
#     'windSpeed': 4.55},
#    {'apparentTemperature': 30.59,
#     'cloudCover': 0.76,
#     'dewPoint': 21.59,
#     'humidity': 0.6,
#     'icon': 'partly-cloudy-night',
#     'ozone': 398.09,
#     'precipAccumulation': 0.006,
#     'precipIntensity': 0.0007,
#     'precipProbability': 0.05,
#     'precipType': 'snow',
#     'pressure': 1022.08,
#     'summary': 'Mostly Cloudy',
#     'temperature': 34.07,
#     'time': 1523318400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 20,
#     'windGust': 7.08,
#     'windSpeed': 3.88},
#    {'apparentTemperature': 29.75,
#     'cloudCover': 0.68,
#     'dewPoint': 21.55,
#     'humidity': 0.63,
#     'icon': 'partly-cloudy-night',
#     'ozone': 398.23,
#     'precipAccumulation': 0.013,
#     'precipIntensity': 0.0016,
#     'precipProbability': 0.06,
#     'precipType': 'snow',
#     'pressure': 1022.47,
#     'summary': 'Mostly Cloudy',
#     'temperature': 32.89,
#     'time': 1523322000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 31,
#     'windGust': 6.34,
#     'windSpeed': 3.44},
#    {'apparentTemperature': 31.57,
#     'cloudCover': 0.68,
#     'dewPoint': 21.23,
#     'humidity': 0.65,
#     'icon': 'partly-cloudy-night',
#     'ozone': 398.87,
#     'precipAccumulation': 0.012,
#     'precipIntensity': 0.0015,
#     'precipProbability': 0.05,
#     'precipType': 'snow',
#     'pressure': 1022.73,
#     'summary': 'Mostly Cloudy',
#     'temperature': 31.57,
#     'time': 1523325600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 46,
#     'windGust': 5.45,
#     'windSpeed': 2.96},
#    {'apparentTemperature': 30.31,
#     'cloudCover': 0.67,
#     'dewPoint': 21.08,
#     'humidity': 0.68,
#     'icon': 'partly-cloudy-night',
#     'ozone': 398.93,
#     'precipAccumulation': 0.004,
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.02,
#     'precipType': 'snow',
#     'pressure': 1022.85,
#     'summary': 'Mostly Cloudy',
#     'temperature': 30.31,
#     'time': 1523329200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 63,
#     'windGust': 4.48,
#     'windSpeed': 2.7},
#    {'apparentTemperature': 29.51,
#     'cloudCover': 0.66,
#     'dewPoint': 21.14,
#     'humidity': 0.71,
#     'icon': 'partly-cloudy-night',
#     'ozone': 397.66,
#     'precipAccumulation': 0.004,
#     'precipIntensity': 0.0005,
#     'precipProbability': 0.02,
#     'precipType': 'snow',
#     'pressure': 1022.74,
#     'summary': 'Mostly Cloudy',
#     'temperature': 29.51,
#     'time': 1523332800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 79,
#     'windGust': 4.09,
#     'windSpeed': 2.59},
#    {'apparentTemperature': 29.22,
#     'cloudCover': 0.64,
#     'dewPoint': 21.28,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-night',
#     'ozone': 395.92,
#     'precipAccumulation': 0.004,
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.02,
#     'precipType': 'snow',
#     'pressure': 1022.64,
#     'summary': 'Mostly Cloudy',
#     'temperature': 29.22,
#     'time': 1523336400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 98,
#     'windGust': 3.99,
#     'windSpeed': 2.58},
#    {'apparentTemperature': 29.14,
#     'cloudCover': 0.63,
#     'dewPoint': 21.36,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-night',
#     'ozone': 395.16,
#     'precipAccumulation': 0.021,
#     'precipIntensity': 0.0022,
#     'precipProbability': 0.04,
#     'precipType': 'snow',
#     'pressure': 1022.39,
#     'summary': 'Mostly Cloudy',
#     'temperature': 29.14,
#     'time': 1523340000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 104,
#     'windGust': 3.73,
#     'windSpeed': 2.42},
#    {'apparentTemperature': 28.84,
#     'cloudCover': 0.64,
#     'dewPoint': 21.81,
#     'humidity': 0.75,
#     'icon': 'partly-cloudy-night',
#     'ozone': 396.22,
#     'precipAccumulation': 0.015,
#     'precipIntensity': 0.0015,
#     'precipProbability': 0.03,
#     'precipType': 'snow',
#     'pressure': 1022.28,
#     'summary': 'Mostly Cloudy',
#     'temperature': 28.84,
#     'time': 1523343600,
#     'uvIndex': 0,
#     'visibility': 9.34,
#     'windBearing': 95,
#     'windGust': 3.59,
#     'windSpeed': 2.22},
#    {'apparentTemperature': 28.36,
#     'cloudCover': 0.93,
#     'dewPoint': 22.13,
#     'humidity': 0.77,
#     'icon': 'partly-cloudy-night',
#     'ozone': 398.3,
#     'precipAccumulation': 0.046,
#     'precipIntensity': 0.0046,
#     'precipProbability': 0.05,
#     'precipType': 'snow',
#     'pressure': 1022.33,
#     'summary': 'Mostly Cloudy',
#     'temperature': 28.36,
#     'time': 1523347200,
#     'uvIndex': 0,
#     'visibility': 4.01,
#     'windBearing': 64,
#     'windGust': 3.5,
#     'windSpeed': 2.12},
#    {'apparentTemperature': 28.18,
#     'cloudCover': 0.94,
#     'dewPoint': 22.35,
#     'humidity': 0.78,
#     'icon': 'snow',
#     'ozone': 400.43,
#     'precipAccumulation': 0.078,
#     'precipIntensity': 0.0078,
#     'precipProbability': 0.07,
#     'precipType': 'snow',
#     'pressure': 1022.35,
#     'summary': 'Possible Light Snow',
#     'temperature': 28.18,
#     'time': 1523350800,
#     'uvIndex': 0,
#     'visibility': 0.58,
#     'windBearing': 45,
#     'windGust': 4.31,
#     'windSpeed': 2.16},
#    {'apparentTemperature': 28.35,
#     'cloudCover': 0.95,
#     'dewPoint': 22.38,
#     'humidity': 0.78,
#     'icon': 'snow',
#     'ozone': 402.55,
#     'precipAccumulation': 0.088,
#     'precipIntensity': 0.0089,
#     'precipProbability': 0.07,
#     'precipType': 'snow',
#     'pressure': 1022.39,
#     'summary': 'Possible Light Snow',
#     'temperature': 28.35,
#     'time': 1523354400,
#     'uvIndex': 0,
#     'visibility': 0,
#     'windBearing': 17,
#     'windGust': 5.25,
#     'windSpeed': 2.64},
#    {'apparentTemperature': 25.48,
#     'cloudCover': 0.96,
#     'dewPoint': 22.34,
#     'humidity': 0.76,
#     'icon': 'snow',
#     'ozone': 404.72,
#     'precipAccumulation': 0.083,
#     'precipIntensity': 0.0087,
#     'precipProbability': 0.08,
#     'precipType': 'snow',
#     'pressure': 1022.5,
#     'summary': 'Possible Light Snow',
#     'temperature': 28.92,
#     'time': 1523358000,
#     'uvIndex': 0,
#     'visibility': 0,
#     'windBearing': 347,
#     'windGust': 6.24,
#     'windSpeed': 3.25},
#    {'apparentTemperature': 26.02,
#     'cloudCover': 0.96,
#     'dewPoint': 22.49,
#     'humidity': 0.73,
#     'icon': 'fog',
#     'ozone': 406.77,
#     'precipAccumulation': 0.07,
#     'precipIntensity': 0.008,
#     'precipProbability': 0.1,
#     'precipType': 'snow',
#     'pressure': 1022.62,
#     'summary': 'Foggy',
#     'temperature': 30.08,
#     'time': 1523361600,
#     'uvIndex': 0,
#     'visibility': 0.18,
#     'windBearing': 328,
#     'windGust': 6.95,
#     'windSpeed': 3.86},
#    {'apparentTemperature': 27.33,
#     'cloudCover': 0.94,
#     'dewPoint': 23.03,
#     'humidity': 0.7,
#     'icon': 'fog',
#     'ozone': 408.25,
#     'precipAccumulation': 0.047,
#     'precipIntensity': 0.0061,
#     'precipProbability': 0.13,
#     'precipType': 'snow',
#     'pressure': 1022.78,
#     'summary': 'Foggy',
#     'temperature': 31.85,
#     'time': 1523365200,
#     'uvIndex': 1,
#     'visibility': 1.82,
#     'windBearing': 320,
#     'windGust': 7,
#     'windSpeed': 4.55},
#    {'apparentTemperature': 29.05,
#     'cloudCover': 0.91,
#     'dewPoint': 23.79,
#     'humidity': 0.66,
#     'icon': 'partly-cloudy-day',
#     'ozone': 409.6,
#     'precipAccumulation': 0.029,
#     'precipIntensity': 0.0038,
#     'precipProbability': 0.14,
#     'precipType': 'snow',
#     'pressure': 1022.9,
#     'summary': 'Mostly Cloudy',
#     'temperature': 33.9,
#     'time': 1523368800,
#     'uvIndex': 1,
#     'visibility': 4.25,
#     'windBearing': 319,
#     'windGust': 6.82,
#     'windSpeed': 5.3},
#    {'apparentTemperature': 30.59,
#     'cloudCover': 0.89,
#     'dewPoint': 24.39,
#     'humidity': 0.63,
#     'icon': 'partly-cloudy-day',
#     'ozone': 411.43,
#     'precipAccumulation': 0.016,
#     'precipIntensity': 0.0021,
#     'precipProbability': 0.12,
#     'precipType': 'snow',
#     'pressure': 1022.9,
#     'summary': 'Mostly Cloudy',
#     'temperature': 35.69,
#     'time': 1523372400,
#     'uvIndex': 2,
#     'visibility': 6.85,
#     'windBearing': 317,
#     'windGust': 7.21,
#     'windSpeed': 6.04},
#    {'apparentTemperature': 32.46,
#     'cloudCover': 0.89,
#     'dewPoint': 24.7,
#     'humidity': 0.59,
#     'icon': 'partly-cloudy-day',
#     'ozone': 414.3,
#     'precipAccumulation': 0.007,
#     'precipIntensity': 0.0009,
#     'precipProbability': 0.07,
#     'precipType': 'snow',
#     'pressure': 1022.61,
#     'summary': 'Mostly Cloudy',
#     'temperature': 37.66,
#     'time': 1523376000,
#     'uvIndex': 3,
#     'visibility': 9.77,
#     'windBearing': 314,
#     'windGust': 8.57,
#     'windSpeed': 6.76},
#    {'apparentTemperature': 34.44,
#     'cloudCover': 0.89,
#     'dewPoint': 24.8,
#     'humidity': 0.55,
#     'icon': 'partly-cloudy-day',
#     'ozone': 417.53,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.04,
#     'precipType': 'snow',
#     'pressure': 1022.16,
#     'summary': 'Mostly Cloudy',
#     'temperature': 39.64,
#     'time': 1523379600,
#     'uvIndex': 3,
#     'visibility': 10,
#     'windBearing': 311,
#     'windGust': 10.41,
#     'windSpeed': 7.46},
#    {'apparentTemperature': 36.85,
#     'cloudCover': 0.88,
#     'dewPoint': 24.41,
#     'humidity': 0.5,
#     'icon': 'partly-cloudy-day',
#     'ozone': 420.71,
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'pressure': 1021.78,
#     'summary': 'Mostly Cloudy',
#     'temperature': 41.89,
#     'time': 1523383200,
#     'uvIndex': 3,
#     'visibility': 10,
#     'windBearing': 309,
#     'windGust': 12.09,
#     'windSpeed': 8.07},
#    {'apparentTemperature': 38.27,
#     'cloudCover': 0.75,
#     'dewPoint': 23.22,
#     'humidity': 0.45,
#     'icon': 'partly-cloudy-day',
#     'ozone': 424.04,
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'pressure': 1021.52,
#     'summary': 'Mostly Cloudy',
#     'temperature': 43.33,
#     'time': 1523386800,
#     'uvIndex': 2,
#     'visibility': 10,
#     'windBearing': 309,
#     'windGust': 13.82,
#     'windSpeed': 8.8},
#    {'apparentTemperature': 38.56,
#     'cloudCover': 0.57,
#     'dewPoint': 21.58,
#     'humidity': 0.41,
#     'icon': 'partly-cloudy-day',
#     'ozone': 427.07,
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1021.28,
#     'summary': 'Partly Cloudy',
#     'temperature': 43.78,
#     'time': 1523390400,
#     'uvIndex': 2,
#     'visibility': 10,
#     'windBearing': 309,
#     'windGust': 15.44,
#     'windSpeed': 9.43},
#    {'apparentTemperature': 37.16,
#     'cloudCover': 0.42,
#     'dewPoint': 20.35,
#     'humidity': 0.41,
#     'icon': 'partly-cloudy-day',
#     'ozone': 428.52,
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1021.2,
#     'summary': 'Partly Cloudy',
#     'temperature': 42.6,
#     'time': 1523394000,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 309,
#     'windGust': 15.56,
#     'windSpeed': 9.29},
#    {'apparentTemperature': 34.95,
#     'cloudCover': 0.34,
#     'dewPoint': 19.76,
#     'humidity': 0.43,
#     'icon': 'partly-cloudy-day',
#     'ozone': 427.8,
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'pressure': 1021.3,
#     'summary': 'Partly Cloudy',
#     'temperature': 40.2,
#     'time': 1523397600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 298,
#     'windGust': 12.94,
#     'windSpeed': 7.76},
#    {'apparentTemperature': 32.19,
#     'cloudCover': 0.27,
#     'dewPoint': 19.51,
#     'humidity': 0.49,
#     'icon': 'partly-cloudy-day',
#     'ozone': 425.42,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.04,
#     'precipType': 'snow',
#     'pressure': 1021.52,
#     'summary': 'Partly Cloudy',
#     'temperature': 36.69,
#     'time': 1523401200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 285,
#     'windGust': 8.79,
#     'windSpeed': 5.49},
#    {'apparentTemperature': 30.67,
#     'cloudCover': 0.21,
#     'dewPoint': 19.59,
#     'humidity': 0.55,
#     'icon': 'clear-night',
#     'ozone': 422.17,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.04,
#     'precipType': 'snow',
#     'pressure': 1021.81,
#     'summary': 'Clear',
#     'temperature': 34.01,
#     'time': 1523404800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 303,
#     'windGust': 5.52,
#     'windSpeed': 3.75},
#    {'apparentTemperature': 29.08,
#     'cloudCover': 0.17,
#     'dewPoint': 19.87,
#     'humidity': 0.61,
#     'icon': 'clear-night',
#     'ozone': 417.46,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.22,
#     'summary': 'Clear',
#     'temperature': 31.95,
#     'time': 1523408400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 21,
#     'windGust': 4.21,
#     'windSpeed': 3.14},
#    {'apparentTemperature': 27.34,
#     'cloudCover': 0.13,
#     'dewPoint': 20.32,
#     'humidity': 0.66,
#     'icon': 'clear-night',
#     'ozone': 411.8,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.66,
#     'summary': 'Clear',
#     'temperature': 30.37,
#     'time': 1523412000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 129,
#     'windGust': 3.85,
#     'windSpeed': 3.09},
#    {'apparentTemperature': 25.63,
#     'cloudCover': 0.11,
#     'dewPoint': 20.75,
#     'humidity': 0.71,
#     'icon': 'clear-night',
#     'ozone': 407.28,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.96,
#     'summary': 'Clear',
#     'temperature': 29.01,
#     'time': 1523415600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 207,
#     'windGust': 3.8,
#     'windSpeed': 3.21},
#    {'apparentTemperature': 24.45,
#     'cloudCover': 0.12,
#     'dewPoint': 21.16,
#     'humidity': 0.74,
#     'icon': 'clear-night',
#     'ozone': 405.04,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.88,
#     'summary': 'Clear',
#     'temperature': 28.29,
#     'time': 1523419200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 228,
#     'windGust': 3.97,
#     'windSpeed': 3.48},
#    {'apparentTemperature': 23.9,
#     'cloudCover': 0.14,
#     'dewPoint': 21.56,
#     'humidity': 0.76,
#     'icon': 'clear-night',
#     'ozone': 403.99,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.64,
#     'summary': 'Clear',
#     'temperature': 28.29,
#     'time': 1523422800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 219,
#     'windGust': 4.44,
#     'windSpeed': 3.91},
#    {'apparentTemperature': 23.6,
#     'cloudCover': 0.14,
#     'dewPoint': 21.77,
#     'humidity': 0.76,
#     'icon': 'clear-night',
#     'ozone': 403.37,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.38,
#     'summary': 'Clear',
#     'temperature': 28.38,
#     'time': 1523426400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 209,
#     'windGust': 4.85,
#     'windSpeed': 4.26},
#    {'apparentTemperature': 23,
#     'cloudCover': 0.17,
#     'dewPoint': 21.73,
#     'humidity': 0.77,
#     'icon': 'clear-night',
#     'ozone': 402.86,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.16,
#     'summary': 'Clear',
#     'temperature': 27.97,
#     'time': 1523430000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 206,
#     'windGust': 4.91,
#     'windSpeed': 4.37},
#    {'apparentTemperature': 22.16,
#     'cloudCover': 0.19,
#     'dewPoint': 21.53,
#     'humidity': 0.79,
#     'icon': 'clear-night',
#     'ozone': 402.78,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1021.96,
#     'summary': 'Clear',
#     'temperature': 27.27,
#     'time': 1523433600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 202,
#     'windGust': 4.92,
#     'windSpeed': 4.39},
#    {'apparentTemperature': 21.78,
#     'cloudCover': 0.22,
#     'dewPoint': 21.42,
#     'humidity': 0.79,
#     'icon': 'clear-night',
#     'ozone': 403.65,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.01,
#     'precipType': 'snow',
#     'pressure': 1021.79,
#     'summary': 'Clear',
#     'temperature': 27.02,
#     'time': 1523437200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 199,
#     'windGust': 5.38,
#     'windSpeed': 4.48},
#    {'apparentTemperature': 22.22,
#     'cloudCover': 0.25,
#     'dewPoint': 21.55,
#     'humidity': 0.78,
#     'icon': 'partly-cloudy-night',
#     'ozone': 405.9,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.01,
#     'precipType': 'snow',
#     'pressure': 1021.68,
#     'summary': 'Partly Cloudy',
#     'temperature': 27.56,
#     'time': 1523440800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 196,
#     'windGust': 6.61,
#     'windSpeed': 4.65},
#    {'apparentTemperature': 23.42,
#     'cloudCover': 0.27,
#     'dewPoint': 21.83,
#     'humidity': 0.75,
#     'icon': 'partly-cloudy-day',
#     'ozone': 409.03,
#     'precipAccumulation': 0,
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.02,
#     'precipType': 'snow',
#     'pressure': 1021.59,
#     'summary': 'Partly Cloudy',
#     'temperature': 28.8,
#     'time': 1523444400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 194,
#     'windGust': 8.29,
#     'windSpeed': 4.89},
#    {'apparentTemperature': 25.53,
#     'cloudCover': 0.27,
#     'dewPoint': 22.14,
#     'humidity': 0.69,
#     'icon': 'partly-cloudy-day',
#     'ozone': 412.17,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1021.35,
#     'summary': 'Partly Cloudy',
#     'temperature': 31,
#     'time': 1523448000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 195,
#     'windGust': 10.13,
#     'windSpeed': 5.42},
#    {'apparentTemperature': 29.3,
#     'cloudCover': 0.22,
#     'dewPoint': 22.42,
#     'humidity': 0.6,
#     'icon': 'clear-day',
#     'ozone': 415.77,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.82,
#     'summary': 'Clear',
#     'temperature': 34.83,
#     'time': 1523451600,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 199,
#     'windGust': 12.17,
#     'windSpeed': 6.42},
#    {'apparentTemperature': 33.71,
#     'cloudCover': 0.16,
#     'dewPoint': 22.75,
#     'humidity': 0.51,
#     'icon': 'clear-day',
#     'ozone': 419.5,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.14,
#     'summary': 'Clear',
#     'temperature': 39.15,
#     'time': 1523455200,
#     'uvIndex': 2,
#     'visibility': 10,
#     'windBearing': 208,
#     'windGust': 14.16,
#     'windSpeed': 7.72},
#    {'apparentTemperature': 37.42,
#     'cloudCover': 0.16,
#     'dewPoint': 23.27,
#     'humidity': 0.46,
#     'icon': 'clear-day',
#     'ozone': 420.5,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1019.35,
#     'summary': 'Clear',
#     'temperature': 42.64,
#     'time': 1523458800,
#     'uvIndex': 3,
#     'visibility': 10,
#     'windBearing': 214,
#     'windGust': 15.68,
#     'windSpeed': 8.81},
#    {'apparentTemperature': 40.18,
#     'cloudCover': 0.28,
#     'dewPoint': 24.02,
#     'humidity': 0.43,
#     'icon': 'partly-cloudy-day',
#     'ozone': 416.37,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1018.43,
#     'summary': 'Partly Cloudy',
#     'temperature': 45.16,
#     'time': 1523462400,
#     'uvIndex': 4,
#     'visibility': 10,
#     'windBearing': 218,
#     'windGust': 16.85,
#     'windSpeed': 9.64},
#    {'apparentTemperature': 43.48,
#     'cloudCover': 0.46,
#     'dewPoint': 24.94,
#     'humidity': 0.4,
#     'icon': 'partly-cloudy-day',
#     'ozone': 409.63,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.43,
#     'summary': 'Partly Cloudy',
#     'temperature': 48.02,
#     'time': 1523466000,
#     'uvIndex': 4,
#     'visibility': 10,
#     'windBearing': 221,
#     'windGust': 17.81,
#     'windSpeed': 10.29},
#    {'apparentTemperature': 50.08,
#     'cloudCover': 0.62,
#     'dewPoint': 26.2,
#     'humidity': 0.39,
#     'icon': 'partly-cloudy-day',
#     'ozone': 404.83,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.47,
#     'summary': 'Mostly Cloudy',
#     'temperature': 50.08,
#     'time': 1523469600,
#     'uvIndex': 4,
#     'visibility': 10,
#     'windBearing': 223,
#     'windGust': 18.6,
#     'windSpeed': 10.76}],
#   'icon': 'snow',
#   'summary': 'Light snow (< 1 in.) tomorrow morning.'},
#  'latitude': 43.048122,
#  'longitude': -76.147424,
#  'minutely': {'data': [{'precipIntensity': 0,
#     'precipProbability': 0,
#     'time': 1523298300},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523298360},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523298420},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523298480},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523298540},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523298600},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523298660},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523298720},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523298780},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523298840},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523298900},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523298960},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299020},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299080},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299140},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299200},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299260},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299320},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299380},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299440},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299500},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299560},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299620},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299680},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299740},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299800},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299860},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299920},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523299980},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300040},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300100},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300160},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300220},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300280},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300340},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300400},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300460},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300520},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300580},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300640},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300700},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300760},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300820},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300880},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523300940},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301000},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301060},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301120},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301180},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301240},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301300},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301360},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301420},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301480},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301540},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301600},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301660},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301720},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301780},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301840},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1523301900}],
#   'icon': 'partly-cloudy-day',
#   'summary': 'Mostly cloudy for the hour.'},
#  'offset': -4,
#  'timezone': 'America/New_York'}

# %%
import requests
# Now I can write the entire program...
location = input("Where are you? (eg. Syracuse, NY) : ")
geodata = google_geocode(location)
coords =geodata['results'][0]['geometry']['location']
weather = darksky_weather(coords)
current = weather['currently']
print("Current conditions in %s are %s with a temperature of %.0f degrees." % 
      (location, current['summary'], current['temperature']))
# Out:
# Where are you? (eg. Syracuse, NY) : Buffalo, NY
# https://api.darksky.net/forecast/3428d875996cccbf7b713a175d3fd7a5/42.886447,-78.878369
# Current conditions in Buffalo, NY are Partly Cloudy with a temperature of 36 degrees.
